# %% [raw]
# import csv
# with open('Data/motor_data.csv') as motordata:
#     reader = csv.reader(motordata)
#     for row in reader:
#         print(row)
#
#     f.close()

# %%
import csv
motordata = csv.DictReader(open('Data/motor_data.csv', 'r'))
motor_list = []    
for line in motordata:
      motor_list.append(line)
motor_list
# Out:
# [OrderedDict([('', '0'),
#               ('Ia', '0.051089999999999997'),
#               ('Ib', '0.10568999999999999'),
#               ('angle', '223'),
#               ('rpm', '1000')]),
#  OrderedDict([('', '1'),
#               ('Ia', '0.04875'),
#               ('Ib', '0.10374'),
#               ('angle', '223'),
#               ('rpm', '1000')]),
#  OrderedDict([('', '2'),
#               ('Ia', '0.05148'),
#               ('Ib', '0.10725'),
#               ('angle', '223'),
#               ('rpm', '1000')]),
#  OrderedDict([('', '3'),
#               ('Ia', '0.0507'),
#               ('Ib', '0.10725'),
#               ('angle', '223'),
#               ('rpm', '1000')]),
#  OrderedDict([('', '4'),
#               ('Ia', '0.0507'),
#               ('Ib', '0.10608'),
#               ('angle', '223'),
#               ('rpm', '1000')]),
#  OrderedDict([('', '5'),
#               ('Ia', '0.051089999999999997'),
#               ('Ib', '0.10881'),
#               ('angle', '223'),
# ...
